# %%
print("Hello, World!" \
"This is a multi-line string." \
"Python is great for scripting.")
# Out:
# Hello, World!This is a multi-line string.Python is great for scripting.

# %% [markdown]
# Notebook
